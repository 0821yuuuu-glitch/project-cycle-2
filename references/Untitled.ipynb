# %% [markdown]
# # 專題循環二：信賴區間與單一樣本推論
#
# ## 1. 研究問題 (Research Questions)
# * [cite_start]**比例分析 (Proportion Analysis)**：2007 年學生目前有飲酒習慣的比例是否與 0.35 有顯著差異？ [cite: 42, 56]
# * [cite_start]**平均數分析 (Mean Analysis)**：2007 年學生的平均體重是否與 68.0 公斤有顯著差異？ [cite: 49, 57]

# %% [markdown]
# ## 2. 變數定義與編碼 (Variable Definition & Coding)
#
# ### [cite_start]行為變數：CurrentAlcoholUse (目前飲酒情況) [cite: 32]
# * [cite_start]**描述**：測量學生在過去 30 天內飲酒的天數 [cite: 66]。
# * [cite_start]**重編碼規則 (Recoding Rule)**： [cite: 37]
#     * **成功 (1)**：原始代碼 2-7（代表有飲酒行為）。
#     * **失敗 (0)**：原始代碼 1（代表無飲酒行為）。
# * [cite_start]**檢定基準值 ($p_0$)**：0.35 [cite: 42]。
#
# ### [cite_start]連續變數：HowMuchDoYouWeighWithoutShoesInKG (體重) [cite: 46]
# * [cite_start]**描述**：學生的體重，單位為公斤 [cite: 66]。
# * **檢定基準值 ($\mu_0$)**：68.0 [cite: 49]。

# %% [markdown]
# ## 3. 統計假設 (Statistical Hypotheses)
#
# ### 平均數檢定 (Mean Analysis)
# * **虛無假設 ($H_0$)**：$\mu = 68.0$
# * **對立假設 ($H_a$)**：$\mu \neq 68.0$
#
# ### 比例檢定 (Proportion Analysis)
# * **虛無假設 ($H_0$)**：$p = 0.35$
# * **對立假設 ($H_a$)**：$p \neq 0.35$

# %% [markdown]
# # Project Cycle 2: Confidence Intervals and One-Sample Inference
#
# ## 1. Research Questions
# * [cite_start]**Proportion Analysis**: Is the proportion of students who currently use alcohol different from 0.35? [cite: 42, 56]
# * [cite_start]**Mean Analysis**: Is the mean weight of students different from 68.0 kg? [cite: 49, 57]

# %% [markdown]
# ## 2. Variable Definition and Coding
#
# ### Behavior Variable: CurrentAlcoholUse
# * [cite_start]**Description**: Number of days alcohol was consumed in the past 30 days[cite: 66].
# * [cite_start]**Recoding Rule**: [cite: 37]
#     * **Success (1)**: Original codes 2-7.
#     * **Failure (0)**: Original code 1.
# * [cite_start]**Benchmark ($p_0$)**: 0.35[cite: 42].
#
# ### Continuous Variable: HowMuchDoYouWeighWithoutShoesInKG
# * **Description**: Student's weight in kilograms[cite: 66].
# * [cite_start]**Benchmark ($\mu_0$)**: 68.0[cite: 49].

# %% [markdown]
# ### Hypotheses for Mean Analysis
# * **Null Hypothesis ($H_0$)**: $\mu = 68.0$
# * **Alternative Hypothesis ($H_a$)**: $\mu \neq 68.0$
#
# ### Hypotheses for Proportion Analysis
# * **Null Hypothesis ($H_0$)**: $p = 0.35$
# * **Alternative Hypothesis ($H_a$)**: $p \neq 0.35$
